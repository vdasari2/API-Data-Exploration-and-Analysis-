# %%
#importing the necessary packages
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %%
#Data is in the URL specified below
url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season=2022-23&SeasonType=Regular%20Season&StatCategory=PTS'

# %%
#Getting the data from the URL and converting it into JSON format
page = requests.get(url).json()

# %%
#Displaying the JSON
page

# %%
#Saving the JSON file
out_file = open("NBAData.json","w")
json.dump(page, out_file, indent=6)

# %%
headers_name = page['resultSet']['headers']

# %%
#Getting all the column names
headers_name
# Out:
# ['PLAYER_ID',
#  'RANK',
#  'PLAYER',
#  'TEAM_ID',
#  'TEAM',
#  'GP',
#  'MIN',
#  'FGM',
#  'FGA',
#  'FG_PCT',
#  'FG3M',
#  'FG3A',
#  'FG3_PCT',
#  'FTM',
#  'FTA',
#  'FT_PCT',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PTS',
#  'EFF']

# %%
#saving the data into a dataframe
final_data = pd.DataFrame(page['resultSet']['rowSet'] ,columns=headers_name)

# %%
#Displaying the dataframe
final_data
# Out:
#      PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  \
# 0      1629029     1              Luka Doncic  1610612742  DAL  53  36.4
# 1       203954     2              Joel Embiid  1610612755  PHI  48  35.1
# 2       203081     3           Damian Lillard  1610612757  POR  47  36.3
# 3       203507     4    Giannis Antetokounmpo  1610612749  MIL  49  32.4
# 4      1628983     5  Shai Gilgeous-Alexander  1610612760  OKC  54  35.5
# ..         ...   ...                      ...         ...  ...  ..   ...
# 249    1630540   250            Miles McBride  1610612752  NYK  49  12.2
# 250    1630586   251             Usman Garuba  1610612745  HOU  54  13.5
# 251    1630194   252                Paul Reed  1610612755  PHI  47   9.5
# 252    1629680   253         Matisse Thybulle  1610612757  POR  53  13.4
# 253    1630550   254                  JT Thor  1610612766  CHA  50  11.2
#
#       FGM   FGA  FG_PCT  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# ...

# %%
#Understanding the data
#describe() method returns the description of the data in the Dataframe
final_data.describe()
# Out:
#           PLAYER_ID        RANK       TEAM_ID          GP         MIN  \
# count  2.540000e+02  254.000000  2.540000e+02  254.000000  254.000000
# mean   1.269072e+06  127.480315  1.610613e+09   53.417323   25.657874
# std    6.219521e+05   73.452343  8.516329e+00    5.613987    7.242616
# min    2.544000e+03    1.000000  1.610613e+09   42.000000    9.500000
# 25%    5.598782e+05   64.250000  1.610613e+09   49.000000   19.725000
# 50%    1.628978e+06  127.500000  1.610613e+09   53.000000   26.700000
# 75%    1.630169e+06  190.750000  1.610613e+09   58.000000   31.875000
# max    1.631223e+06  254.000000  1.610613e+09   64.000000   37.500000
#
#               FGM         FGA      FG_PCT        FG3M        FG3A  ...  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000  ...
# mean     4.527953    9.507480    0.482516    1.330709    3.678740  ...
# std      2.329661    4.870901    0.076717    0.914228    2.393936  ...
# ...

# %%
#Checking if the there are any null values in any of the columns and getting the count
final_data.isnull().sum()
# Out:
# PLAYER_ID    0
# RANK         0
# PLAYER       0
# TEAM_ID      0
# TEAM         0
# GP           0
# MIN          0
# FGM          0
# FGA          0
# FG_PCT       0
# FG3M         0
# FG3A         0
# FG3_PCT      0
# FTM          0
# FTA          0
# FT_PCT       0
# OREB         0
# DREB         0
# REB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PTS          0
# EFF          0
# dtype: int64

# %%
#Getting the data types of each column 
final_data.dtypes
# Out:
# PLAYER_ID      int64
# RANK           int64
# PLAYER        object
# TEAM_ID        int64
# TEAM          object
# GP             int64
# MIN          float64
# FGM          float64
# FGA          float64
# FG_PCT       float64
# FG3M         float64
# FG3A         float64
# FG3_PCT      float64
# FTM          float64
# FTA          float64
# FT_PCT       float64
# OREB         float64
# DREB         float64
# REB          float64
# AST          float64
# STL          float64
# BLK          float64
# TOV          float64
# PTS          float64
# EFF          float64
# dtype: object

# %%
#coverting the data into a CSV  file 
final_data.to_csv('Final_NBA_Data.csv', index=False)
